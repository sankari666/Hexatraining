# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder \
    .appName("RDD") \
    .getOrCreate()

# %%
transactions = [
"DEPOSIT",
"WITHDRAW",
"TRANSFER",
"DEPOSIT",
"BALANCE_CHECK",
"TRANSFER",
"DEPOSIT",
"WITHDRAW",
"LOAN_PAYMENT",
"DEPOSIT",
"TRANSFER",
"WITHDRAW",
"DEPOSIT",
"BALANCE_CHECK",
"TRANSFER",
"DEPOSIT",
"WITHDRAW",
"LOAN_PAYMENT",
"TRANSFER",
"DEPOSIT",
"WITHDRAW",
"DEPOSIT",
"TRANSFER",
"BALANCE_CHECK",
"WITHDRAW",
"DEPOSIT",
"TRANSFER",
"LOAN_PAYMENT",
"DEPOSIT",
"WITHDRAW",
"TRANSFER",
"DEPOSIT",
"BALANCE_CHECK",
"TRANSFER",
"WITHDRAW",
"DEPOSIT",
"TRANSFER",
"LOAN_PAYMENT",
"DEPOSIT",
"WITHDRAW",
"TRANSFER",
"BALANCE_CHECK",
"DEPOSIT",
"TRANSFER",
"WITHDRAW",
"LOAN_PAYMENT",
"DEPOSIT",
"TRANSFER",
"BALANCE_CHECK",
"DEPOSIT"
]

# %%
rdd = spark.sparkContext.parallelize(transactions)

# %%
rdd.collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT']

# %%
rdd.count()
# Out:
# 50

# %%
rdd.first()
# Out:
# 'DEPOSIT'

# %%
rdd.take(15)
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER']

# %%
rdd.distinct().collect()
# Out:
# ['DEPOSIT', 'WITHDRAW', 'TRANSFER', 'BALANCE_CHECK', 'LOAN_PAYMENT']

# %%
rdd.distinct().count()
# Out:
# 5

# %%
rdd.sortBy(lambda x: x).collect()
# Out:
# ['BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW']

# %%
rdd.map(lambda x: x.lower()).collect()
# Out:
# ['deposit',
#  'withdraw',
#  'transfer',
#  'deposit',
#  'balance_check',
#  'transfer',
#  'deposit',
#  'withdraw',
#  'loan_payment',
#  'deposit',
#  'transfer',
#  'withdraw',
#  'deposit',
#  'balance_check',
#  'transfer',
#  'deposit',
#  'withdraw',
#  'loan_payment',
#  'transfer',
#  'deposit',
#  'withdraw',
#  'deposit',
#  'transfer',
#  'balance_check',
#  'withdraw',
#  'deposit',
#  'transfer',
#  'loan_payment',
#  'deposit',
#  'withdraw',
#  'transfer',
#  'deposit',
#  'balance_check',
#  'transfer',
#  'withdraw',
#  'deposit',
#  'transfer',
#  'loan_payment',
#  'deposit',
#  'withdraw',
#  'transfer',
#  'balance_check',
#  'deposit',
#  'transfer',
#  'withdraw',
#  'loan_payment',
#  'deposit',
#  'transfer',
#  'balance_check',
#  'deposit']

# %%
rdd.map(lambda x: x.upper()).collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT']

# %%
rdd.map(lambda x: (x, len(x))).collect()
# Out:
# [('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('BALANCE_CHECK', 13),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('LOAN_PAYMENT', 12),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('WITHDRAW', 8),
#  ('DEPOSIT', 7),
#  ('BALANCE_CHECK', 13),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('LOAN_PAYMENT', 12),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('BALANCE_CHECK', 13),
#  ('WITHDRAW', 8),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('LOAN_PAYMENT', 12),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('BALANCE_CHECK', 13),
#  ('TRANSFER', 8),
#  ('WITHDRAW', 8),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('LOAN_PAYMENT', 12),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('TRANSFER', 8),
#  ('BALANCE_CHECK', 13),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('WITHDRAW', 8),
#  ('LOAN_PAYMENT', 12),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
# ...

# %%
rdd.filter(lambda x: x == "DEPOSIT").collect()
# Out:
# ['DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT']

# %%
rdd.filter(lambda x: x == "WITHDRAW").collect()
# Out:
# ['WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW']

# %%
rdd.filter(lambda x: x == "TRANSFER").collect()
# Out:
# ['TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER']

# %%
rdd.filter(lambda x: x == "LOAN_PAYMENT").collect()
# Out:
# ['LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT']

# %%
rdd.filter(lambda x: "CHECK" in x).collect()
# Out:
# ['BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK']

# %%
rdd.filter(lambda x: x != "DEPOSIT").collect()
# Out:
# ['WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'WITHDRAW',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'BALANCE_CHECK']

# %%
rdd.filter(lambda x: x != "TRANSFER").collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'DEPOSIT',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'DEPOSIT',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'DEPOSIT']

# %%
rdd.filter(lambda x: len(x) > 8).collect()
# Out:
# ['BALANCE_CHECK',
#  'LOAN_PAYMENT',
#  'BALANCE_CHECK',
#  'LOAN_PAYMENT',
#  'BALANCE_CHECK',
#  'LOAN_PAYMENT',
#  'BALANCE_CHECK',
#  'LOAN_PAYMENT',
#  'BALANCE_CHECK',
#  'LOAN_PAYMENT',
#  'BALANCE_CHECK']

# %%
rdd.filter(lambda x: len(x) < 10).collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'DEPOSIT']

# %%
rdd.filter(lambda x: x.startswith("B")).collect()
# Out:
# ['BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK']

# %%
rdd.map(lambda x: f"BANK_{x}").collect()
# Out:
# ['BANK_DEPOSIT',
#  'BANK_WITHDRAW',
#  'BANK_TRANSFER',
#  'BANK_DEPOSIT',
#  'BANK_BALANCE_CHECK',
#  'BANK_TRANSFER',
#  'BANK_DEPOSIT',
#  'BANK_WITHDRAW',
#  'BANK_LOAN_PAYMENT',
#  'BANK_DEPOSIT',
#  'BANK_TRANSFER',
#  'BANK_WITHDRAW',
#  'BANK_DEPOSIT',
#  'BANK_BALANCE_CHECK',
#  'BANK_TRANSFER',
#  'BANK_DEPOSIT',
#  'BANK_WITHDRAW',
#  'BANK_LOAN_PAYMENT',
#  'BANK_TRANSFER',
#  'BANK_DEPOSIT',
#  'BANK_WITHDRAW',
#  'BANK_DEPOSIT',
#  'BANK_TRANSFER',
#  'BANK_BALANCE_CHECK',
#  'BANK_WITHDRAW',
#  'BANK_DEPOSIT',
#  'BANK_TRANSFER',
#  'BANK_LOAN_PAYMENT',
#  'BANK_DEPOSIT',
#  'BANK_WITHDRAW',
#  'BANK_TRANSFER',
#  'BANK_DEPOSIT',
#  'BANK_BALANCE_CHECK',
#  'BANK_TRANSFER',
#  'BANK_WITHDRAW',
#  'BANK_DEPOSIT',
#  'BANK_TRANSFER',
#  'BANK_LOAN_PAYMENT',
#  'BANK_DEPOSIT',
#  'BANK_WITHDRAW',
#  'BANK_TRANSFER',
#  'BANK_BALANCE_CHECK',
#  'BANK_DEPOSIT',
#  'BANK_TRANSFER',
#  'BANK_WITHDRAW',
#  'BANK_LOAN_PAYMENT',
#  'BANK_DEPOSIT',
#  'BANK_TRANSFER',
# ...

# %%
rdd.map(lambda x: f"{x}_2025").collect()
# Out:
# ['DEPOSIT_2025',
#  'WITHDRAW_2025',
#  'TRANSFER_2025',
#  'DEPOSIT_2025',
#  'BALANCE_CHECK_2025',
#  'TRANSFER_2025',
#  'DEPOSIT_2025',
#  'WITHDRAW_2025',
#  'LOAN_PAYMENT_2025',
#  'DEPOSIT_2025',
#  'TRANSFER_2025',
#  'WITHDRAW_2025',
#  'DEPOSIT_2025',
#  'BALANCE_CHECK_2025',
#  'TRANSFER_2025',
#  'DEPOSIT_2025',
#  'WITHDRAW_2025',
#  'LOAN_PAYMENT_2025',
#  'TRANSFER_2025',
#  'DEPOSIT_2025',
#  'WITHDRAW_2025',
#  'DEPOSIT_2025',
#  'TRANSFER_2025',
#  'BALANCE_CHECK_2025',
#  'WITHDRAW_2025',
#  'DEPOSIT_2025',
#  'TRANSFER_2025',
#  'LOAN_PAYMENT_2025',
#  'DEPOSIT_2025',
#  'WITHDRAW_2025',
#  'TRANSFER_2025',
#  'DEPOSIT_2025',
#  'BALANCE_CHECK_2025',
#  'TRANSFER_2025',
#  'WITHDRAW_2025',
#  'DEPOSIT_2025',
#  'TRANSFER_2025',
#  'LOAN_PAYMENT_2025',
#  'DEPOSIT_2025',
#  'WITHDRAW_2025',
#  'TRANSFER_2025',
#  'BALANCE_CHECK_2025',
#  'DEPOSIT_2025',
#  'TRANSFER_2025',
#  'WITHDRAW_2025',
#  'LOAN_PAYMENT_2025',
#  'DEPOSIT_2025',
#  'TRANSFER_2025',
# ...

# %%
rdd.map(lambda x: (x, len(x))).collect()
# Out:
# [('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('BALANCE_CHECK', 13),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('LOAN_PAYMENT', 12),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('WITHDRAW', 8),
#  ('DEPOSIT', 7),
#  ('BALANCE_CHECK', 13),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('LOAN_PAYMENT', 12),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('BALANCE_CHECK', 13),
#  ('WITHDRAW', 8),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('LOAN_PAYMENT', 12),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('BALANCE_CHECK', 13),
#  ('TRANSFER', 8),
#  ('WITHDRAW', 8),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('LOAN_PAYMENT', 12),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('TRANSFER', 8),
#  ('BALANCE_CHECK', 13),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('WITHDRAW', 8),
#  ('LOAN_PAYMENT', 12),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
# ...

# %%
rdd.map(lambda x: (x, 1)).collect()
# Out:
# [('DEPOSIT', 1),
#  ('WITHDRAW', 1),
#  ('TRANSFER', 1),
#  ('DEPOSIT', 1),
#  ('BALANCE_CHECK', 1),
#  ('TRANSFER', 1),
#  ('DEPOSIT', 1),
#  ('WITHDRAW', 1),
#  ('LOAN_PAYMENT', 1),
#  ('DEPOSIT', 1),
#  ('TRANSFER', 1),
#  ('WITHDRAW', 1),
#  ('DEPOSIT', 1),
#  ('BALANCE_CHECK', 1),
#  ('TRANSFER', 1),
#  ('DEPOSIT', 1),
#  ('WITHDRAW', 1),
#  ('LOAN_PAYMENT', 1),
#  ('TRANSFER', 1),
#  ('DEPOSIT', 1),
#  ('WITHDRAW', 1),
#  ('DEPOSIT', 1),
#  ('TRANSFER', 1),
#  ('BALANCE_CHECK', 1),
#  ('WITHDRAW', 1),
#  ('DEPOSIT', 1),
#  ('TRANSFER', 1),
#  ('LOAN_PAYMENT', 1),
#  ('DEPOSIT', 1),
#  ('WITHDRAW', 1),
#  ('TRANSFER', 1),
#  ('DEPOSIT', 1),
#  ('BALANCE_CHECK', 1),
#  ('TRANSFER', 1),
#  ('WITHDRAW', 1),
#  ('DEPOSIT', 1),
#  ('TRANSFER', 1),
#  ('LOAN_PAYMENT', 1),
#  ('DEPOSIT', 1),
#  ('WITHDRAW', 1),
#  ('TRANSFER', 1),
#  ('BALANCE_CHECK', 1),
#  ('DEPOSIT', 1),
#  ('TRANSFER', 1),
#  ('WITHDRAW', 1),
#  ('LOAN_PAYMENT', 1),
#  ('DEPOSIT', 1),
#  ('TRANSFER', 1),
# ...

# %%
rdd.map(lambda x: x.replace("DEPOSIT", "CASH_DEPOSIT")).collect()
# Out:
# ['CASH_DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'CASH_DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'CASH_DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'CASH_DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'CASH_DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'CASH_DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'CASH_DEPOSIT',
#  'WITHDRAW',
#  'CASH_DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'CASH_DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'CASH_DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'CASH_DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'CASH_DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'CASH_DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'CASH_DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'CASH_DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'CASH_DEPOSIT']

# %%
rdd.map(lambda x: x.replace("WITHDRAW", "CASH_WITHDRAWAL")).collect()
# Out:
# ['DEPOSIT',
#  'CASH_WITHDRAWAL',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'CASH_WITHDRAWAL',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'CASH_WITHDRAWAL',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'CASH_WITHDRAWAL',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'DEPOSIT',
#  'CASH_WITHDRAWAL',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'CASH_WITHDRAWAL',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'CASH_WITHDRAWAL',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'CASH_WITHDRAWAL',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'CASH_WITHDRAWAL',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'TRANSFER',
#  'CASH_WITHDRAWAL',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT']

# %%
rdd.map(lambda x: x[::-1]).collect()
# Out:
# ['TISOPED',
#  'WARDHTIW',
#  'REFSNART',
#  'TISOPED',
#  'KCEHC_ECNALAB',
#  'REFSNART',
#  'TISOPED',
#  'WARDHTIW',
#  'TNEMYAP_NAOL',
#  'TISOPED',
#  'REFSNART',
#  'WARDHTIW',
#  'TISOPED',
#  'KCEHC_ECNALAB',
#  'REFSNART',
#  'TISOPED',
#  'WARDHTIW',
#  'TNEMYAP_NAOL',
#  'REFSNART',
#  'TISOPED',
#  'WARDHTIW',
#  'TISOPED',
#  'REFSNART',
#  'KCEHC_ECNALAB',
#  'WARDHTIW',
#  'TISOPED',
#  'REFSNART',
#  'TNEMYAP_NAOL',
#  'TISOPED',
#  'WARDHTIW',
#  'REFSNART',
#  'TISOPED',
#  'KCEHC_ECNALAB',
#  'REFSNART',
#  'WARDHTIW',
#  'TISOPED',
#  'REFSNART',
#  'TNEMYAP_NAOL',
#  'TISOPED',
#  'WARDHTIW',
#  'REFSNART',
#  'KCEHC_ECNALAB',
#  'TISOPED',
#  'REFSNART',
#  'WARDHTIW',
#  'TNEMYAP_NAOL',
#  'TISOPED',
#  'REFSNART',
#  'KCEHC_ECNALAB',
#  'TISOPED']

# %%
rdd.map(lambda x: x[:3]).collect()
# Out:
# ['DEP',
#  'WIT',
#  'TRA',
#  'DEP',
#  'BAL',
#  'TRA',
#  'DEP',
#  'WIT',
#  'LOA',
#  'DEP',
#  'TRA',
#  'WIT',
#  'DEP',
#  'BAL',
#  'TRA',
#  'DEP',
#  'WIT',
#  'LOA',
#  'TRA',
#  'DEP',
#  'WIT',
#  'DEP',
#  'TRA',
#  'BAL',
#  'WIT',
#  'DEP',
#  'TRA',
#  'LOA',
#  'DEP',
#  'WIT',
#  'TRA',
#  'DEP',
#  'BAL',
#  'TRA',
#  'WIT',
#  'DEP',
#  'TRA',
#  'LOA',
#  'DEP',
#  'WIT',
#  'TRA',
#  'BAL',
#  'DEP',
#  'TRA',
#  'WIT',
#  'LOA',
#  'DEP',
#  'TRA',
#  'BAL',
#  'DEP']

# %%
rdd.map(lambda x: x[-4:]).collect()
# Out:
# ['OSIT',
#  'DRAW',
#  'SFER',
#  'OSIT',
#  'HECK',
#  'SFER',
#  'OSIT',
#  'DRAW',
#  'MENT',
#  'OSIT',
#  'SFER',
#  'DRAW',
#  'OSIT',
#  'HECK',
#  'SFER',
#  'OSIT',
#  'DRAW',
#  'MENT',
#  'SFER',
#  'OSIT',
#  'DRAW',
#  'OSIT',
#  'SFER',
#  'HECK',
#  'DRAW',
#  'OSIT',
#  'SFER',
#  'MENT',
#  'OSIT',
#  'DRAW',
#  'SFER',
#  'OSIT',
#  'HECK',
#  'SFER',
#  'DRAW',
#  'OSIT',
#  'SFER',
#  'MENT',
#  'OSIT',
#  'DRAW',
#  'SFER',
#  'HECK',
#  'OSIT',
#  'SFER',
#  'DRAW',
#  'MENT',
#  'OSIT',
#  'SFER',
#  'HECK',
#  'OSIT']

# %%
def get_code(x):
    mapping = {"DEPOSIT": "D", "WITHDRAW": "W", "TRANSFER": "T"}
    return mapping.get(x, "UNKNOWN")
rdd.map(get_code).collect()
# Out:
# ['D',
#  'W',
#  'T',
#  'D',
#  'UNKNOWN',
#  'T',
#  'D',
#  'W',
#  'UNKNOWN',
#  'D',
#  'T',
#  'W',
#  'D',
#  'UNKNOWN',
#  'T',
#  'D',
#  'W',
#  'UNKNOWN',
#  'T',
#  'D',
#  'W',
#  'D',
#  'T',
#  'UNKNOWN',
#  'W',
#  'D',
#  'T',
#  'UNKNOWN',
#  'D',
#  'W',
#  'T',
#  'D',
#  'UNKNOWN',
#  'T',
#  'W',
#  'D',
#  'T',
#  'UNKNOWN',
#  'D',
#  'W',
#  'T',
#  'UNKNOWN',
#  'D',
#  'T',
#  'W',
#  'UNKNOWN',
#  'D',
#  'T',
#  'UNKNOWN',
#  'D']

# %%
rdd.distinct().collect()
# Out:
# ['DEPOSIT', 'WITHDRAW', 'TRANSFER', 'BALANCE_CHECK', 'LOAN_PAYMENT']

# %%
rdd.distinct().count()
# Out:
# 5

# %%
rdd.distinct().sortBy(lambda x: x).collect()
# Out:
# ['BALANCE_CHECK', 'DEPOSIT', 'LOAN_PAYMENT', 'TRANSFER', 'WITHDRAW']

# %%
rdd.distinct().filter(lambda x: "PAYMENT" in x).collect()
# Out:
# ['LOAN_PAYMENT']

# %%
rdd.distinct().filter(lambda x: "CHECK" in x).collect()
# Out:
# ['BALANCE_CHECK']

# %%
rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b).collect()
# Out:
# [('DEPOSIT', 16),
#  ('WITHDRAW', 10),
#  ('TRANSFER', 13),
#  ('BALANCE_CHECK', 6),
#  ('LOAN_PAYMENT', 5)]

# %%
frequencies = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
frequencies.max(key=lambda x: x[1])
# Out:
# ('DEPOSIT', 16)

# %%
frequencies = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
frequencies.min(key=lambda x: x[1])
# Out:
# ('LOAN_PAYMENT', 5)

# %%
rdd.countByValue()
# Out:
# defaultdict(int,
#             {'DEPOSIT': 16,
#              'WITHDRAW': 10,
#              'TRANSFER': 13,
#              'BALANCE_CHECK': 6,
#              'LOAN_PAYMENT': 5})

# %%
frequencies = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
frequencies.filter(lambda x: x[1] > 5).collect()
# Out:
# [('DEPOSIT', 16), ('WITHDRAW', 10), ('TRANSFER', 13), ('BALANCE_CHECK', 6)]

# %%
extra_transactions = [
"DEPOSIT",
"ATM_WITHDRAWAL",
"TRANSFER",
"MOBILE_RECHARGE",
"BALANCE_CHECK"
]

# %%
rdd2 = spark.sparkContext.parallelize(extra_transactions)

# %%
union_rdd = rdd.union(rdd2)
union_rdd.collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'DEPOSIT',
#  'ATM_WITHDRAWAL',
#  'TRANSFER',
#  'MOBILE_RECHARGE',
#  'BALANCE_CHECK']

# %%
union_rdd.count()
# Out:
# 55

# %%
union_rdd.distinct().collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'LOAN_PAYMENT',
#  'ATM_WITHDRAWAL',
#  'MOBILE_RECHARGE']

# %%
rdd2.subtract(rdd).distinct().collect()
# Out:
# ['ATM_WITHDRAWAL', 'MOBILE_RECHARGE']

# %%
union_rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b).collect()
# Out:
# [('DEPOSIT', 17),
#  ('WITHDRAW', 10),
#  ('TRANSFER', 14),
#  ('BALANCE_CHECK', 7),
#  ('LOAN_PAYMENT', 5),
#  ('ATM_WITHDRAWAL', 1),
#  ('MOBILE_RECHARGE', 1)]

# %%
rdd3 = spark.sparkContext.parallelize([
"DEPOSIT",
"TRANSFER",
"BALANCE_CHECK",
"CREDIT_CARD_PAYMENT",
"ATM_WITHDRAWAL"
])

# %%
common_rdd = rdd.intersection(rdd3)
common_rdd.collect()
# Out:
# ['DEPOSIT', 'TRANSFER', 'BALANCE_CHECK']

# %%
common_rdd.count()
# Out:
# 3

# %%
common_rdd.sortBy(lambda x: x).collect()
# Out:
# ['BALANCE_CHECK', 'DEPOSIT', 'TRANSFER']

# %%
common_rdd.filter(lambda x: "CHECK" in x).collect()
# Out:
# ['BALANCE_CHECK']

# %%
common_rdd.filter(lambda x: "TRANSFER" in x).collect()
# Out:
# ['TRANSFER']

# %%
amounts = [
500,1200,3000,4500,800,950,
1100,2500,4000,6000,
750,1800,2200,3300,4700,
5200,1500,2600,3700,4800,
5900,6200,700,900,1400,
1750,2100,2900,3600,4300,
5100,5800,6500,7200,8100,
9200,10500,12000,13500,15000,
17000,19000,22000,25000,28000,
30000,32000,35000,38000,40000
]

# %%
amount_rdd = spark.sparkContext.parallelize(amounts)

# %%
amount_rdd.sum()
# Out:
# 463750

# %%
amount_rdd.mean()
# Out:
# 9275.0

# %%
amount_rdd.max()
# Out:
# 40000

# %%
amount_rdd.min()
# Out:
# 500

# %%
amount_rdd.filter(lambda x: x > 10000).collect()
# Out:
# [10500,
#  12000,
#  13500,
#  15000,
#  17000,
#  19000,
#  22000,
#  25000,
#  28000,
#  30000,
#  32000,
#  35000,
#  38000,
#  40000]

# %%
amount_rdd.filter(lambda x: x < 2000).collect()
# Out:
# [500, 1200, 800, 950, 1100, 750, 1800, 1500, 700, 900, 1400, 1750]

# %%
amount_rdd.map(lambda x: x + 500).collect()
# Out:
# [1000,
#  1700,
#  3500,
#  5000,
#  1300,
#  1450,
#  1600,
#  3000,
#  4500,
#  6500,
#  1250,
#  2300,
#  2700,
#  3800,
#  5200,
#  5700,
#  2000,
#  3100,
#  4200,
#  5300,
#  6400,
#  6700,
#  1200,
#  1400,
#  1900,
#  2250,
#  2600,
#  3400,
#  4100,
#  4800,
#  5600,
#  6300,
#  7000,
#  7700,
#  8600,
#  9700,
#  11000,
#  12500,
#  14000,
#  15500,
#  17500,
#  19500,
#  22500,
#  25500,
#  28500,
#  30500,
#  32500,
#  35500,
#  38500,
#  40500]

# %%
amount_rdd.map(lambda x: x * 1.10).collect()
# Out:
# [550.0,
#  1320.0,
#  3300.0000000000005,
#  4950.0,
#  880.0000000000001,
#  1045.0,
#  1210.0,
#  2750.0,
#  4400.0,
#  6600.000000000001,
#  825.0000000000001,
#  1980.0000000000002,
#  2420.0,
#  3630.0000000000005,
#  5170.0,
#  5720.000000000001,
#  1650.0000000000002,
#  2860.0000000000005,
#  4070.0000000000005,
#  5280.0,
#  6490.000000000001,
#  6820.000000000001,
#  770.0000000000001,
#  990.0000000000001,
#  1540.0000000000002,
#  1925.0000000000002,
#  2310.0,
#  3190.0000000000005,
#  3960.0000000000005,
#  4730.0,
#  5610.0,
#  6380.000000000001,
#  7150.000000000001,
#  7920.000000000001,
#  8910.0,
#  10120.0,
#  11550.000000000002,
#  13200.000000000002,
#  14850.000000000002,
#  16500.0,
#  18700.0,
#  20900.0,
#  24200.000000000004,
#  27500.000000000004,
#  30800.000000000004,
#  33000.0,
#  35200.0,
#  38500.0,
#  41800.0,
#  44000.0]

# %%
amount_rdd.sortBy(lambda x: x, ascending=True).collect()
# Out:
# [500,
#  700,
#  750,
#  800,
#  900,
#  950,
#  1100,
#  1200,
#  1400,
#  1500,
#  1750,
#  1800,
#  2100,
#  2200,
#  2500,
#  2600,
#  2900,
#  3000,
#  3300,
#  3600,
#  3700,
#  4000,
#  4300,
#  4500,
#  4700,
#  4800,
#  5100,
#  5200,
#  5800,
#  5900,
#  6000,
#  6200,
#  6500,
#  7200,
#  8100,
#  9200,
#  10500,
#  12000,
#  13500,
#  15000,
#  17000,
#  19000,
#  22000,
#  25000,
#  28000,
#  30000,
#  32000,
#  35000,
#  38000,
#  40000]

# %%
amount_rdd.sortBy(lambda x: x, ascending=False).collect()
# Out:
# [40000,
#  38000,
#  35000,
#  32000,
#  30000,
#  28000,
#  25000,
#  22000,
#  19000,
#  17000,
#  15000,
#  13500,
#  12000,
#  10500,
#  9200,
#  8100,
#  7200,
#  6500,
#  6200,
#  6000,
#  5900,
#  5800,
#  5200,
#  5100,
#  4800,
#  4700,
#  4500,
#  4300,
#  4000,
#  3700,
#  3600,
#  3300,
#  3000,
#  2900,
#  2600,
#  2500,
#  2200,
#  2100,
#  1800,
#  1750,
#  1500,
#  1400,
#  1200,
#  1100,
#  950,
#  900,
#  800,
#  750,
#  700,
#  500]

# %%
amount_rdd.top(10)
# Out:
# [40000, 38000, 35000, 32000, 30000, 28000, 25000, 22000, 19000, 17000]

# %%
amount_rdd.takeOrdered(10)
# Out:
# [500, 700, 750, 800, 900, 950, 1100, 1200, 1400, 1500]

# %%
amount_rdd.filter(lambda x: x > 5000).count()
# Out:
# 24

# %%
amount_rdd.filter(lambda x: x > 20000).count()
# Out:
# 8

# %%
amount_rdd.filter(lambda x: x > 10000).sum()
# Out:
# 337000

# %%
customer_comments = [
"service was excellent",
"mobile banking is easy",
"transfer completed quickly",
"deposit process was smooth",
"excellent customer support",
"loan payment completed successfully",
"banking app is excellent",
"service is fast and reliable"
]

# %%
comment_rdd = spark.sparkContext.parallelize(customer_comments)

# %%
words_rdd = rdd.flatMap(lambda line: line.split(" "))
words_rdd.collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT']

# %%
words_rdd.count()
# Out:
# 50

# %%
words_rdd.distinct().collect()
# Out:
# ['DEPOSIT', 'WITHDRAW', 'TRANSFER', 'BALANCE_CHECK', 'LOAN_PAYMENT']

# %%
words_rdd.sortBy(lambda word: word.lower()).collect()
# Out:
# ['BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW']

# %%
word_counts = words_rdd.map(lambda word: (word, 1)).reduceByKey(lambda a, b: a + b)
word_counts.collect()
# Out:
# [('DEPOSIT', 16),
#  ('WITHDRAW', 10),
#  ('TRANSFER', 13),
#  ('BALANCE_CHECK', 6),
#  ('LOAN_PAYMENT', 5)]

# %%
words_rdd.filter(lambda word: "service" in word.lower()).collect()
# Out:
# []

# %%
words_rdd.filter(lambda word: "excellent" in word.lower()).collect()
# Out:
# []

# %%
words_rdd.map(lambda word: word.upper()).collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT']

# %%
words_rdd.max(key=lambda word: len(word))
# Out:
# 'BALANCE_CHECK'

# %%
words_rdd.min(key=lambda word: len(word))
# Out:
# 'DEPOSIT'

# %%
word_counts.max(key=lambda x: x[1])
# Out:
# ('DEPOSIT', 16)

# %%
word_counts.min(key=lambda x: x[1])
# Out:
# ('LOAN_PAYMENT', 5)

# %%
words_rdd.filter(lambda word: word.lower().startswith("b")).count()
# Out:
# 6

# %%
words_rdd.filter(lambda word: word.lower().endswith("ly")).count()
# Out:
# 0

# %%
word_counts.sortBy(lambda x: x[1], ascending=False).collect()
# Out:
# [('DEPOSIT', 16),
#  ('TRANSFER', 13),
#  ('WITHDRAW', 10),
#  ('BALANCE_CHECK', 6),
#  ('LOAN_PAYMENT', 5)]

# %%
total = rdd.count()
deposit_pct = (rdd.filter(lambda x: x == "DEPOSIT").count() / total) * 100

# %%
transfer_pct = (rdd.filter(lambda x: x == "TRANSFER").count() / total) * 100

# %%
withdraw_pct = (rdd.filter(lambda x: x == "WITHDRAW").count() / total) * 100

# %%
freq_rdd = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
freq_rdd.max(key=lambda x: x)
# Out:
# ('WITHDRAW', 10)

# %%
freq_rdd.min(key=lambda x: x)
# Out:
# ('BALANCE_CHECK', 6)

# %%
rdd.countByValue()
# Out:
# defaultdict(int,
#             {'DEPOSIT': 16,
#              'WITHDRAW': 10,
#              'TRANSFER': 13,
#              'BALANCE_CHECK': 6,
#              'LOAN_PAYMENT': 5})

# %%
rdd.distinct().collect()
# Out:
# ['DEPOSIT', 'WITHDRAW', 'TRANSFER', 'BALANCE_CHECK', 'LOAN_PAYMENT']

# %%
freq_rdd.collect()
# Out:
# [('DEPOSIT', 16),
#  ('WITHDRAW', 10),
#  ('TRANSFER', 13),
#  ('BALANCE_CHECK', 6),
#  ('LOAN_PAYMENT', 5)]

# %%
rdd.distinct().saveAsTextFile("output/unique_transactions")

# %%
freq_rdd.saveAsTextFile("output/transaction_frequencies")

# %%
rdd.count()
# Out:
# 50

# %%
freq_rdd.takeOrdered(3, key=lambda x: -x[1])
# Out:
# [('DEPOSIT', 16), ('TRANSFER', 13), ('WITHDRAW', 10)]

# %%
freq_rdd.takeOrdered(3, key=lambda x: x[1])
# Out:
# [('LOAN_PAYMENT', 5), ('BALANCE_CHECK', 6), ('WITHDRAW', 10)]

# %%
freq_rdd.sortBy(lambda x: x[1], ascending=False).collect()
# Out:
# [('DEPOSIT', 16),
#  ('TRANSFER', 13),
#  ('WITHDRAW', 10),
#  ('BALANCE_CHECK', 6),
#  ('LOAN_PAYMENT', 5)]

# %%
metrics = {
    "Total Activities": rdd.count(),
    "Unique Types": rdd.distinct().count(),
    "Breakdown": freq_rdd.collect()
}
print(metrics)
# Out:
# {'Total Activities': 50, 'Unique Types': 5, 'Breakdown': [('DEPOSIT', 16), ('WITHDRAW', 10), ('TRANSFER', 13), ('BALANCE_CHECK', 6), ('LOAN_PAYMENT', 5)]}

# %%
amount_rdd.sum()
# Out:
# 463750

# %%
amount_rdd.mean()
# Out:
# 9275.0

# %%
amount_rdd.filter(lambda x: x > 20000).collect()
# Out:
# [22000, 25000, 28000, 30000, 32000, 35000, 38000, 40000]

# %%
amount_rdd.filter(lambda x: x < 1000).collect()
# Out:
# [500, 800, 950, 750, 700, 900]

# %%
dashboard = {
    "Total Volume Count": rdd.count(),
    "Total Value Processed": amount_rdd.sum(),
    "Average Value": amount_rdd.mean(),
    "Max Transaction": amount_rdd.max(),
    "Min Transaction": amount_rdd.min()
}
for metric, value in dashboard.items():
    print(f"{metric}: {value}")
# Out:
# Total Volume Count: 50
# Total Value Processed: 463750
# Average Value: 9275.0
# Max Transaction: 40000
# Min Transaction: 500
