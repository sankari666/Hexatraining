# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder \
    .appName("RDD") \
    .getOrCreate()

# %%
activities = [
"LOGIN",
"COURSE_VIEW",
"LOGIN",
"VIDEO_PLAY",
"QUIZ_START",
"VIDEO_PLAY",
"LOGIN",
"COURSE_VIEW",
"ASSIGNMENT_SUBMIT",
"VIDEO_PLAY",
"QUIZ_START",
"QUIZ_COMPLETE",
"LOGIN",
"VIDEO_PLAY",
"COURSE_VIEW",
"LOGIN",
"VIDEO_PLAY",
"VIDEO_PLAY",
"QUIZ_START",
"LOGIN",
"COURSE_VIEW",
"COURSE_VIEW",
"ASSIGNMENT_SUBMIT",
"LOGIN",
"VIDEO_PLAY",
"QUIZ_COMPLETE",
"LOGIN",
"COURSE_VIEW",
"VIDEO_PLAY",
"VIDEO_PLAY",
"LOGIN",
"COURSE_VIEW",
"QUIZ_START",
"ASSIGNMENT_SUBMIT",
"LOGIN",
"VIDEO_PLAY",
"LOGIN",
"COURSE_VIEW",
"QUIZ_COMPLETE",
"VIDEO_PLAY",
"LOGIN",
"COURSE_VIEW",
"VIDEO_PLAY",
"LOGIN",
"QUIZ_START",
"COURSE_VIEW",
"VIDEO_PLAY",
"ASSIGNMENT_SUBMIT",
"LOGIN",
"VIDEO_PLAY"
]

# %%
rdd = spark.sparkContext.parallelize(activities)

# %%
rdd.collect()
# Out:
# ['LOGIN',
#  'COURSE_VIEW',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'LOGIN',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'QUIZ_START',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'QUIZ_COMPLETE',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'QUIZ_START',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'VIDEO_PLAY']

# %%
rdd.count()
# Out:
# 50

# %%
rdd.first()
# Out:
# 'LOGIN'

# %%
rdd.take(10)
# Out:
# ['LOGIN',
#  'COURSE_VIEW',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY']

# %%
rdd.collect()[-1]
# Out:
# 'VIDEO_PLAY'

# %%
rdd.distinct().collect()
# Out:
# ['COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'QUIZ_START']

# %%
rdd.distinct().count()
# Out:
# 6

# %%
rdd.sortBy(lambda x: x.lower()).collect()
# Out:
# ['ASSIGNMENT_SUBMIT',
#  'ASSIGNMENT_SUBMIT',
#  'ASSIGNMENT_SUBMIT',
#  'ASSIGNMENT_SUBMIT',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'QUIZ_COMPLETE',
#  'QUIZ_COMPLETE',
#  'QUIZ_COMPLETE',
#  'QUIZ_START',
#  'QUIZ_START',
#  'QUIZ_START',
#  'QUIZ_START',
#  'QUIZ_START',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY']

# %%
rdd.map(lambda x: x.upper()).collect()
# Out:
# ['LOGIN',
#  'COURSE_VIEW',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'LOGIN',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'QUIZ_START',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'QUIZ_COMPLETE',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'QUIZ_START',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'VIDEO_PLAY']

# %%
rdd.map(lambda x: (x, len(x))).collect()
# Out:
# [('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('LOGIN', 5),
#  ('VIDEO_PLAY', 10),
#  ('QUIZ_START', 10),
#  ('VIDEO_PLAY', 10),
#  ('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('ASSIGNMENT_SUBMIT', 17),
#  ('VIDEO_PLAY', 10),
#  ('QUIZ_START', 10),
#  ('QUIZ_COMPLETE', 13),
#  ('LOGIN', 5),
#  ('VIDEO_PLAY', 10),
#  ('COURSE_VIEW', 11),
#  ('LOGIN', 5),
#  ('VIDEO_PLAY', 10),
#  ('VIDEO_PLAY', 10),
#  ('QUIZ_START', 10),
#  ('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('COURSE_VIEW', 11),
#  ('ASSIGNMENT_SUBMIT', 17),
#  ('LOGIN', 5),
#  ('VIDEO_PLAY', 10),
#  ('QUIZ_COMPLETE', 13),
#  ('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('VIDEO_PLAY', 10),
#  ('VIDEO_PLAY', 10),
#  ('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('QUIZ_START', 10),
#  ('ASSIGNMENT_SUBMIT', 17),
#  ('LOGIN', 5),
#  ('VIDEO_PLAY', 10),
#  ('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('QUIZ_COMPLETE', 13),
#  ('VIDEO_PLAY', 10),
#  ('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('VIDEO_PLAY', 10),
#  ('LOGIN', 5),
#  ('QUIZ_START', 10),
# ...

# %%
rdd.filter(lambda x: x == "LOGIN").collect()
# Out:
# ['LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN']

# %%
rdd.filter(lambda x: x == "VIDEO_PLAY").collect()
# Out:
# ['VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY']

# %%
rdd.filter(lambda x: x == "QUIZ_START").collect()
# Out:
# ['QUIZ_START', 'QUIZ_START', 'QUIZ_START', 'QUIZ_START', 'QUIZ_START']

# %%
rdd.filter(lambda x: "QUIZ" in x).collect()
# Out:
# ['QUIZ_START',
#  'QUIZ_START',
#  'QUIZ_COMPLETE',
#  'QUIZ_START',
#  'QUIZ_COMPLETE',
#  'QUIZ_START',
#  'QUIZ_COMPLETE',
#  'QUIZ_START']

# %%
rdd.filter(lambda x: x.endswith("VIEW")).collect()
# Out:
# ['COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW']

# %%
rdd.filter(lambda x: x != "LOGIN").collect()
# Out:
# ['COURSE_VIEW',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'QUIZ_COMPLETE',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY',
#  'QUIZ_COMPLETE',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'QUIZ_START',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'QUIZ_COMPLETE',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY']

# %%
rdd.filter(lambda x: x != "VIDEO_PLAY").collect()
# Out:
# ['LOGIN',
#  'COURSE_VIEW',
#  'LOGIN',
#  'QUIZ_START',
#  'LOGIN',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'QUIZ_START',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'COURSE_VIEW',
#  'LOGIN',
#  'QUIZ_START',
#  'LOGIN',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'COURSE_VIEW',
#  'LOGIN',
#  'COURSE_VIEW',
#  'QUIZ_START',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'LOGIN',
#  'COURSE_VIEW',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'COURSE_VIEW',
#  'LOGIN',
#  'QUIZ_START',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN']

# %%
rdd.filter(lambda x: len(x) > 8).collect()
# Out:
# ['COURSE_VIEW',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'QUIZ_COMPLETE',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY',
#  'QUIZ_COMPLETE',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'QUIZ_START',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'QUIZ_COMPLETE',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY']

# %%
rdd.filter(lambda x: len(x) < 10).collect()
# Out:
# ['LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN',
#  'LOGIN']

# %%
rdd.filter(lambda x: x.startswith("C")).collect()
# Out:
# ['COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'COURSE_VIEW']

# %%
rdd.map(lambda x: x.lower()).collect()
# Out:
# ['login',
#  'course_view',
#  'login',
#  'video_play',
#  'quiz_start',
#  'video_play',
#  'login',
#  'course_view',
#  'assignment_submit',
#  'video_play',
#  'quiz_start',
#  'quiz_complete',
#  'login',
#  'video_play',
#  'course_view',
#  'login',
#  'video_play',
#  'video_play',
#  'quiz_start',
#  'login',
#  'course_view',
#  'course_view',
#  'assignment_submit',
#  'login',
#  'video_play',
#  'quiz_complete',
#  'login',
#  'course_view',
#  'video_play',
#  'video_play',
#  'login',
#  'course_view',
#  'quiz_start',
#  'assignment_submit',
#  'login',
#  'video_play',
#  'login',
#  'course_view',
#  'quiz_complete',
#  'video_play',
#  'login',
#  'course_view',
#  'video_play',
#  'login',
#  'quiz_start',
#  'course_view',
#  'video_play',
#  'assignment_submit',
#  'login',
#  'video_play']

# %%
rdd.map(lambda x: f"EVENT_{x}").collect()
# Out:
# ['EVENT_LOGIN',
#  'EVENT_COURSE_VIEW',
#  'EVENT_LOGIN',
#  'EVENT_VIDEO_PLAY',
#  'EVENT_QUIZ_START',
#  'EVENT_VIDEO_PLAY',
#  'EVENT_LOGIN',
#  'EVENT_COURSE_VIEW',
#  'EVENT_ASSIGNMENT_SUBMIT',
#  'EVENT_VIDEO_PLAY',
#  'EVENT_QUIZ_START',
#  'EVENT_QUIZ_COMPLETE',
#  'EVENT_LOGIN',
#  'EVENT_VIDEO_PLAY',
#  'EVENT_COURSE_VIEW',
#  'EVENT_LOGIN',
#  'EVENT_VIDEO_PLAY',
#  'EVENT_VIDEO_PLAY',
#  'EVENT_QUIZ_START',
#  'EVENT_LOGIN',
#  'EVENT_COURSE_VIEW',
#  'EVENT_COURSE_VIEW',
#  'EVENT_ASSIGNMENT_SUBMIT',
#  'EVENT_LOGIN',
#  'EVENT_VIDEO_PLAY',
#  'EVENT_QUIZ_COMPLETE',
#  'EVENT_LOGIN',
#  'EVENT_COURSE_VIEW',
#  'EVENT_VIDEO_PLAY',
#  'EVENT_VIDEO_PLAY',
#  'EVENT_LOGIN',
#  'EVENT_COURSE_VIEW',
#  'EVENT_QUIZ_START',
#  'EVENT_ASSIGNMENT_SUBMIT',
#  'EVENT_LOGIN',
#  'EVENT_VIDEO_PLAY',
#  'EVENT_LOGIN',
#  'EVENT_COURSE_VIEW',
#  'EVENT_QUIZ_COMPLETE',
#  'EVENT_VIDEO_PLAY',
#  'EVENT_LOGIN',
#  'EVENT_COURSE_VIEW',
#  'EVENT_VIDEO_PLAY',
#  'EVENT_LOGIN',
# ...

# %%
rdd.map(lambda x: f"{x}_2025").collect()
# Out:
# ['LOGIN_2025',
#  'COURSE_VIEW_2025',
#  'LOGIN_2025',
#  'VIDEO_PLAY_2025',
#  'QUIZ_START_2025',
#  'VIDEO_PLAY_2025',
#  'LOGIN_2025',
#  'COURSE_VIEW_2025',
#  'ASSIGNMENT_SUBMIT_2025',
#  'VIDEO_PLAY_2025',
#  'QUIZ_START_2025',
#  'QUIZ_COMPLETE_2025',
#  'LOGIN_2025',
#  'VIDEO_PLAY_2025',
#  'COURSE_VIEW_2025',
#  'LOGIN_2025',
#  'VIDEO_PLAY_2025',
#  'VIDEO_PLAY_2025',
#  'QUIZ_START_2025',
#  'LOGIN_2025',
#  'COURSE_VIEW_2025',
#  'COURSE_VIEW_2025',
#  'ASSIGNMENT_SUBMIT_2025',
#  'LOGIN_2025',
#  'VIDEO_PLAY_2025',
#  'QUIZ_COMPLETE_2025',
#  'LOGIN_2025',
#  'COURSE_VIEW_2025',
#  'VIDEO_PLAY_2025',
#  'VIDEO_PLAY_2025',
#  'LOGIN_2025',
#  'COURSE_VIEW_2025',
#  'QUIZ_START_2025',
#  'ASSIGNMENT_SUBMIT_2025',
#  'LOGIN_2025',
#  'VIDEO_PLAY_2025',
#  'LOGIN_2025',
#  'COURSE_VIEW_2025',
#  'QUIZ_COMPLETE_2025',
#  'VIDEO_PLAY_2025',
#  'LOGIN_2025',
#  'COURSE_VIEW_2025',
#  'VIDEO_PLAY_2025',
#  'LOGIN_2025',
#  'QUIZ_START_2025',
#  'COURSE_VIEW_2025',
# ...

# %%
rdd.map(lambda x: len(x)).collect()
# Out:
# [5,
#  11,
#  5,
#  10,
#  10,
#  10,
#  5,
#  11,
#  17,
#  10,
#  10,
#  13,
#  5,
#  10,
#  11,
#  5,
#  10,
#  10,
#  10,
#  5,
#  11,
#  11,
#  17,
#  5,
#  10,
#  13,
#  5,
#  11,
#  10,
#  10,
#  5,
#  11,
#  10,
#  17,
#  5,
#  10,
#  5,
#  11,
#  13,
#  10,
#  5,
#  11,
#  10,
#  5,
#  10,
#  11,
#  10,
#  17,
#  5,
#  10]

# %%
rdd.map(lambda x: (x, len(x))).collect()
# Out:
# [('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('LOGIN', 5),
#  ('VIDEO_PLAY', 10),
#  ('QUIZ_START', 10),
#  ('VIDEO_PLAY', 10),
#  ('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('ASSIGNMENT_SUBMIT', 17),
#  ('VIDEO_PLAY', 10),
#  ('QUIZ_START', 10),
#  ('QUIZ_COMPLETE', 13),
#  ('LOGIN', 5),
#  ('VIDEO_PLAY', 10),
#  ('COURSE_VIEW', 11),
#  ('LOGIN', 5),
#  ('VIDEO_PLAY', 10),
#  ('VIDEO_PLAY', 10),
#  ('QUIZ_START', 10),
#  ('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('COURSE_VIEW', 11),
#  ('ASSIGNMENT_SUBMIT', 17),
#  ('LOGIN', 5),
#  ('VIDEO_PLAY', 10),
#  ('QUIZ_COMPLETE', 13),
#  ('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('VIDEO_PLAY', 10),
#  ('VIDEO_PLAY', 10),
#  ('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('QUIZ_START', 10),
#  ('ASSIGNMENT_SUBMIT', 17),
#  ('LOGIN', 5),
#  ('VIDEO_PLAY', 10),
#  ('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('QUIZ_COMPLETE', 13),
#  ('VIDEO_PLAY', 10),
#  ('LOGIN', 5),
#  ('COURSE_VIEW', 11),
#  ('VIDEO_PLAY', 10),
#  ('LOGIN', 5),
#  ('QUIZ_START', 10),
# ...

# %%
rdd.map(lambda x: (x, 1)).collect()
# Out:
# [('LOGIN', 1),
#  ('COURSE_VIEW', 1),
#  ('LOGIN', 1),
#  ('VIDEO_PLAY', 1),
#  ('QUIZ_START', 1),
#  ('VIDEO_PLAY', 1),
#  ('LOGIN', 1),
#  ('COURSE_VIEW', 1),
#  ('ASSIGNMENT_SUBMIT', 1),
#  ('VIDEO_PLAY', 1),
#  ('QUIZ_START', 1),
#  ('QUIZ_COMPLETE', 1),
#  ('LOGIN', 1),
#  ('VIDEO_PLAY', 1),
#  ('COURSE_VIEW', 1),
#  ('LOGIN', 1),
#  ('VIDEO_PLAY', 1),
#  ('VIDEO_PLAY', 1),
#  ('QUIZ_START', 1),
#  ('LOGIN', 1),
#  ('COURSE_VIEW', 1),
#  ('COURSE_VIEW', 1),
#  ('ASSIGNMENT_SUBMIT', 1),
#  ('LOGIN', 1),
#  ('VIDEO_PLAY', 1),
#  ('QUIZ_COMPLETE', 1),
#  ('LOGIN', 1),
#  ('COURSE_VIEW', 1),
#  ('VIDEO_PLAY', 1),
#  ('VIDEO_PLAY', 1),
#  ('LOGIN', 1),
#  ('COURSE_VIEW', 1),
#  ('QUIZ_START', 1),
#  ('ASSIGNMENT_SUBMIT', 1),
#  ('LOGIN', 1),
#  ('VIDEO_PLAY', 1),
#  ('LOGIN', 1),
#  ('COURSE_VIEW', 1),
#  ('QUIZ_COMPLETE', 1),
#  ('VIDEO_PLAY', 1),
#  ('LOGIN', 1),
#  ('COURSE_VIEW', 1),
#  ('VIDEO_PLAY', 1),
#  ('LOGIN', 1),
#  ('QUIZ_START', 1),
#  ('COURSE_VIEW', 1),
# ...

# %%
rdd.map(lambda x: x.replace("LOGIN", "USER_LOGIN")).collect()
# Out:
# ['USER_LOGIN',
#  'COURSE_VIEW',
#  'USER_LOGIN',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'VIDEO_PLAY',
#  'USER_LOGIN',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'QUIZ_COMPLETE',
#  'USER_LOGIN',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'USER_LOGIN',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'USER_LOGIN',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'USER_LOGIN',
#  'VIDEO_PLAY',
#  'QUIZ_COMPLETE',
#  'USER_LOGIN',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'USER_LOGIN',
#  'COURSE_VIEW',
#  'QUIZ_START',
#  'ASSIGNMENT_SUBMIT',
#  'USER_LOGIN',
#  'VIDEO_PLAY',
#  'USER_LOGIN',
#  'COURSE_VIEW',
#  'QUIZ_COMPLETE',
#  'VIDEO_PLAY',
#  'USER_LOGIN',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'USER_LOGIN',
#  'QUIZ_START',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'ASSIGNMENT_SUBMIT',
#  'USER_LOGIN',
#  'VIDEO_PLAY']

# %%
rdd.map(lambda x: x.replace("VIDEO_PLAY", "WATCH_VIDEO")).collect()
# Out:
# ['LOGIN',
#  'COURSE_VIEW',
#  'LOGIN',
#  'WATCH_VIDEO',
#  'QUIZ_START',
#  'WATCH_VIDEO',
#  'LOGIN',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'WATCH_VIDEO',
#  'QUIZ_START',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'WATCH_VIDEO',
#  'COURSE_VIEW',
#  'LOGIN',
#  'WATCH_VIDEO',
#  'WATCH_VIDEO',
#  'QUIZ_START',
#  'LOGIN',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'WATCH_VIDEO',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'COURSE_VIEW',
#  'WATCH_VIDEO',
#  'WATCH_VIDEO',
#  'LOGIN',
#  'COURSE_VIEW',
#  'QUIZ_START',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'WATCH_VIDEO',
#  'LOGIN',
#  'COURSE_VIEW',
#  'QUIZ_COMPLETE',
#  'WATCH_VIDEO',
#  'LOGIN',
#  'COURSE_VIEW',
#  'WATCH_VIDEO',
#  'LOGIN',
#  'QUIZ_START',
#  'COURSE_VIEW',
#  'WATCH_VIDEO',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'WATCH_VIDEO']

# %%
rdd.map(lambda x: x[::-1]).collect()
# Out:
# ['NIGOL',
#  'WEIV_ESRUOC',
#  'NIGOL',
#  'YALP_OEDIV',
#  'TRATS_ZIUQ',
#  'YALP_OEDIV',
#  'NIGOL',
#  'WEIV_ESRUOC',
#  'TIMBUS_TNEMNGISSA',
#  'YALP_OEDIV',
#  'TRATS_ZIUQ',
#  'ETELPMOC_ZIUQ',
#  'NIGOL',
#  'YALP_OEDIV',
#  'WEIV_ESRUOC',
#  'NIGOL',
#  'YALP_OEDIV',
#  'YALP_OEDIV',
#  'TRATS_ZIUQ',
#  'NIGOL',
#  'WEIV_ESRUOC',
#  'WEIV_ESRUOC',
#  'TIMBUS_TNEMNGISSA',
#  'NIGOL',
#  'YALP_OEDIV',
#  'ETELPMOC_ZIUQ',
#  'NIGOL',
#  'WEIV_ESRUOC',
#  'YALP_OEDIV',
#  'YALP_OEDIV',
#  'NIGOL',
#  'WEIV_ESRUOC',
#  'TRATS_ZIUQ',
#  'TIMBUS_TNEMNGISSA',
#  'NIGOL',
#  'YALP_OEDIV',
#  'NIGOL',
#  'WEIV_ESRUOC',
#  'ETELPMOC_ZIUQ',
#  'YALP_OEDIV',
#  'NIGOL',
#  'WEIV_ESRUOC',
#  'YALP_OEDIV',
#  'NIGOL',
#  'TRATS_ZIUQ',
#  'WEIV_ESRUOC',
#  'YALP_OEDIV',
#  'TIMBUS_TNEMNGISSA',
#  'NIGOL',
#  'YALP_OEDIV']

# %%
rdd.map(lambda x: x[0] if len(x) > 0 else "").collect()
# Out:
# ['L',
#  'C',
#  'L',
#  'V',
#  'Q',
#  'V',
#  'L',
#  'C',
#  'A',
#  'V',
#  'Q',
#  'Q',
#  'L',
#  'V',
#  'C',
#  'L',
#  'V',
#  'V',
#  'Q',
#  'L',
#  'C',
#  'C',
#  'A',
#  'L',
#  'V',
#  'Q',
#  'L',
#  'C',
#  'V',
#  'V',
#  'L',
#  'C',
#  'Q',
#  'A',
#  'L',
#  'V',
#  'L',
#  'C',
#  'Q',
#  'V',
#  'L',
#  'C',
#  'V',
#  'L',
#  'Q',
#  'C',
#  'V',
#  'A',
#  'L',
#  'V']

# %%
rdd.distinct().collect()
# Out:
# ['COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'QUIZ_START']

# %%
rdd.distinct().count()
# Out:
# 6

# %%
rdd.distinct().sortBy(lambda x: x.lower()).collect()
# Out:
# ['ASSIGNMENT_SUBMIT',
#  'COURSE_VIEW',
#  'LOGIN',
#  'QUIZ_COMPLETE',
#  'QUIZ_START',
#  'VIDEO_PLAY']

# %%
rdd.distinct().filter(lambda x: "QUIZ" in x).collect()
# Out:
# ['QUIZ_COMPLETE', 'QUIZ_START']

# %%
rdd.distinct().filter(lambda x: "COURSE" in x).collect()
# Out:
# ['COURSE_VIEW']

# %%
rdd.countByValue()
# Out:
# defaultdict(int,
#             {'LOGIN': 14,
#              'COURSE_VIEW': 10,
#              'VIDEO_PLAY': 14,
#              'QUIZ_START': 5,
#              'ASSIGNMENT_SUBMIT': 4,
#              'QUIZ_COMPLETE': 3})

# %%
freq_rdd = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
freq_rdd.max(key=lambda x: x[1])
# Out:
# ('LOGIN', 14)

# %%
freq_rdd = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
freq_rdd.min(key=lambda x: x[1])
# Out:
# ('QUIZ_COMPLETE', 3)

# %%
freq_rdd = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
freq_rdd.sortBy(lambda x: x[1], ascending=False).collect()
# Out:
# [('LOGIN', 14),
#  ('VIDEO_PLAY', 14),
#  ('COURSE_VIEW', 10),
#  ('QUIZ_START', 5),
#  ('ASSIGNMENT_SUBMIT', 4),
#  ('QUIZ_COMPLETE', 3)]

# %%
freq_rdd = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b)
freq_rdd.filter(lambda x: x[1] > 5).collect()
# Out:
# [('COURSE_VIEW', 10), ('LOGIN', 14), ('VIDEO_PLAY', 14)]

# %%
extra_activities = [
"LOGIN",
"CERTIFICATE_DOWNLOAD",
"VIDEO_PLAY",
"PROFILE_UPDATE",
"QUIZ_COMPLETE"
]

# %%
rdd2 = spark.sparkContext.parallelize(extra_activities)

# %%
union_rdd = rdd.union(rdd2)
union_rdd.collect()
# Out:
# ['LOGIN',
#  'COURSE_VIEW',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'COURSE_VIEW',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'LOGIN',
#  'COURSE_VIEW',
#  'COURSE_VIEW',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'QUIZ_COMPLETE',
#  'LOGIN',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'QUIZ_START',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'QUIZ_COMPLETE',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'QUIZ_START',
#  'COURSE_VIEW',
#  'VIDEO_PLAY',
#  'ASSIGNMENT_SUBMIT',
#  'LOGIN',
#  'VIDEO_PLAY',
#  'LOGIN',
#  'CERTIFICATE_DOWNLOAD',
#  'VIDEO_PLAY',
#  'PROFILE_UPDATE',
#  'QUIZ_COMPLETE']

# %%
union_rdd.count()
# Out:
# 55

# %%
union_rdd.distinct().collect()
# Out:
# ['ASSIGNMENT_SUBMIT',
#  'QUIZ_COMPLETE',
#  'VIDEO_PLAY',
#  'QUIZ_START',
#  'CERTIFICATE_DOWNLOAD',
#  'PROFILE_UPDATE',
#  'COURSE_VIEW',
#  'LOGIN']

# %%
union_rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b).collect()
# Out:
# [('ASSIGNMENT_SUBMIT', 4),
#  ('QUIZ_COMPLETE', 4),
#  ('VIDEO_PLAY', 15),
#  ('QUIZ_START', 5),
#  ('CERTIFICATE_DOWNLOAD', 1),
#  ('PROFILE_UPDATE', 1),
#  ('COURSE_VIEW', 10),
#  ('LOGIN', 15)]

# %%
rdd2.subtract(rdd).distinct().collect()
# Out:
# ['CERTIFICATE_DOWNLOAD', 'PROFILE_UPDATE']

# %%
rdd3 = spark.sparkContext.parallelize([
"LOGIN",
"COURSE_VIEW",
"PROFILE_UPDATE",
"QUIZ_COMPLETE",
"PAYMENT_SUCCESS"
])

# %%
common_rdd = rdd.intersection(rdd3)
common_rdd.collect()
# Out:
# ['QUIZ_COMPLETE', 'COURSE_VIEW', 'LOGIN']

# %%
common_rdd.count()
# Out:
# 3

# %%
common_rdd.sortBy(lambda x: x.lower()).collect()
# Out:
# ['COURSE_VIEW', 'LOGIN', 'QUIZ_COMPLETE']

# %%
common_rdd.filter(lambda x: "QUIZ" in x).collect()
# Out:
# ['QUIZ_COMPLETE']

# %%
common_rdd.filter(lambda x: "LOGIN" in x).collect()
# Out:
# ['LOGIN']

# %%
numbers = [
120,
250,
300,
450,
600,
750,
900,
1050,
1200,
1350,
1500,
1650,
1800,
1950,
2100
]

# %%
sales_rdd = spark.sparkContext.parallelize(numbers)

# %%
sales_rdd.reduce(lambda a, b: a + b)
# Out:
# 15970

# %%
sales_rdd.reduce(lambda a, b: a if a > b else b)
# Out:
# 2100

# %%
sales_rdd.reduce(lambda a, b: a if a < b else b)
# Out:
# 120

# %%
total = sales_rdd.reduce(lambda a, b: a + b)
total_count = sales_rdd.count()
average = total / total_count if total_count > 0 else 0

# %%
sales_rdd.filter(lambda x: x > 1000).count()
# Out:
# 8

# %%
sales_rdd.map(lambda x: x * 2).collect()
# Out:
# [240,
#  500,
#  600,
#  900,
#  1200,
#  1500,
#  1800,
#  2100,
#  2400,
#  2700,
#  3000,
#  3300,
#  3600,
#  3900,
#  4200]

# %%
sales_rdd.map(lambda x: x + 100).collect()
# Out:
# [220,
#  350,
#  400,
#  550,
#  700,
#  850,
#  1000,
#  1150,
#  1300,
#  1450,
#  1600,
#  1750,
#  1900,
#  2050,
#  2200]

# %%
sales_rdd.sortBy(lambda x: x, ascending=True).collect()
# Out:
# [120,
#  250,
#  300,
#  450,
#  600,
#  750,
#  900,
#  1050,
#  1200,
#  1350,
#  1500,
#  1650,
#  1800,
#  1950,
#  2100]

# %%
sales_rdd.sortBy(lambda x: x, ascending=False).collect()
# Out:
# [2100,
#  1950,
#  1800,
#  1650,
#  1500,
#  1350,
#  1200,
#  1050,
#  900,
#  750,
#  600,
#  450,
#  300,
#  250,
#  120]

# %%
sales_rdd.top(5)
# Out:
# [2100, 1950, 1800, 1650, 1500]

# %%
freq_rdd.max(key=lambda x: x[1])
# Out:
# ('LOGIN', 14)

# %%
freq_rdd.min(key=lambda x: x[1])
# Out:
# ('QUIZ_COMPLETE', 3)

# %%
total_count = rdd.count()
login_pct = (rdd.filter(lambda x: x == "LOGIN").count() / total_count) * 100 if total_count > 0 else 0

# %%
video_pct = (rdd.filter(lambda x: x == "VIDEO_PLAY").count() / total_count) * 100 if total_count > 0 else 0

# %%
activity_report = rdd.collect()

# %%
unique_report = rdd.distinct().collect()

# %%
frequency_report = freq_rdd.collect()

# %%
rdd.distinct().saveAsTextFile("output/distinct_activities")

# %%
freq_rdd.map(lambda x: f"{x[0]}: {x[1]}").saveAsTextFile("output/activity_frequencies")

# %%
usage_summary = {
    "Total Logged Events": rdd.count(),
    "Unique Feature Types": rdd.distinct().count(),
    "Activity Breakdown": freq_rdd.sortBy(lambda x: x[1], ascending=False).collect()
}
print(usage_summary)
# Out:
# {'Total Logged Events': 50, 'Unique Feature Types': 5, 'Activity Breakdown': [('LOGIN', 14), ('VIDEO_PLAY', 14), ('COURSE_VIEW', 10), ('QUIZ_START', 5), ('ASSIGNMENT_SUBMIT', 4), ('QUIZ_COMPLETE', 3)]}
